# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# %pip install tensorflow opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.8.0.76)
# Requirement already satisfied: mediapipe in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.10.5)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.22.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.54.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: attrs>=19.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: opencv-contrib-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: sounddevice>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: CFFI>=1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.37.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.6.6)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.5.1)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 2023-10-01 20:59:24.405 Python[1430:22733] CMIOMS: PlugInMain
# 2023-10-01 20:59:24.405 Python[1430:22733] CMIOMS: HardwarePlugIn_QueryInterface
# 2023-10-01 20:59:24.405 Python[1430:22733] CMIOMS: HardwarePlugIn_Release sRefCount now = 0
# 2023-10-01 20:59:24.405 Python[1430:22733] CMIOMS: HardwarePlugIn_InitializeWithObjectID self=0x296705028
# 2023-10-01 20:59:24.406 Python[1430:22733] LvdlServer	ImgReciever
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceUID self=0x296705028 data(id)=054c
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyTransportType self=0x296705028 data(int)=1651274862
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1684629094
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1869180523
# 2023-10-01 20:59:24.406 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.407 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1885762592
# 2023-10-01 20:59:24.407 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.407 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyDirection self=0x296705028 data(int)=1
# 2023-10-01 20:59:24.420 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceCanBeDefaultDevice self=0x296705028 data(int)=1
# 2023-10-01 20:59:24.420 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyHogMode self=0x296705028 data(int)=-1
# 2023-10-01 20:59:24.421 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyDeviceIsRunningSomewhere self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.421 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceIsRunningSomewhere self=0x296705028 data(int)=1
# 2023-10-01 20:59:24.421 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.421 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyDeviceUID self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceUID self=0x296705028 data(id)=054c
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for Unknown selector: tdps
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) Unknown selector: tdps self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nefc
# 2023-10-01 20:59:24.422 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nefc self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyDeviceIsAlive self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyDeviceIsAlive self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceIsAlive self=0x296705028 data(int)=1
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for Unknown selector: tdps
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) Unknown selector: tdps self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1818850926
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1651797110
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.423 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1651798900
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1869180523
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1937009955
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1886156132
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Device(34) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1935833461
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.424 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for Unknown selector: artd
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) Unknown selector: artd self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.425 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.426 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.427 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.428 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.429 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.430 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.431 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.432 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.433 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyPlugIn self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyPlugIn self=0x296705028 data(int)=33
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyName self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIOObjectPropertyName self=0x296705028 data(id)=Sony Camera (Imaging Edge)
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyTransportType self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyTransportType self=0x296705028 data(int)=1651274862
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.434 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Stream(35) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1885762592
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: Stream unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nefc
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nefc self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: sfam
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: sfam self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.435 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: neep
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: neep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: paep
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: paep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nels
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nels self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nils
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nils self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: etcr
# 2023-10-01 20:59:24.436 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: etcr self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Stream(35) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1919120496
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: Stream unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: zrts
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: zrts self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nedf
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nedf self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: edbh
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: edbh self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: hslf
# 2023-10-01 20:59:24.437 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: hslf self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRate self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Stream(35) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1852207732
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: Stream unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyMinimumFrameRate self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectSetPropertyData Stream(35) kCMIOObjectPropertyListenerAdded self=0x296705028 data(int)=1835430516
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: Stream unhandled setPropertyDataWithAddress for kCMIOObjectPropertyListenerAdded
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.438 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: ccsa
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: ccsa self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.439 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nefc
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nefc self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.440 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: neep
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: neep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: paep
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: paep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nels
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nels self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nils
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nils self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: etcr
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: etcr self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.441 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFormatDescriptions self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyFormatDescriptions self=0x296705028 data(id)=(
#     "<CMVideoFormatDescription 0x2996209e0 [0x1e6f53720]> {\n\tmediaType:'vide' \n\tmediaSubType:'2vuy' \n\tmediaSpecific: {\n\t\tcodecType: '2vuy'\t\tdimensions: 1280 x 720 \n\t} \n\textensions: {(null)}\n}"
# )
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 size=16
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.442 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 data(int)=0
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: zrts
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: zrts self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.443 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nefc
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nefc self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: neep
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: neep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.444 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: paep
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: paep self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nels
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nels self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: nils
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: nils self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: etcr
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: etcr self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFormatDescription self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyFormatDescription self=0x296705028 data(id)=<CMVideoFormatDescription 0x2996246c0 [0x1e6f53720]> {
# 	mediaType:'vide'
# 	mediaSubType:'2vuy'
# 	mediaSpecific: {
# 		codecType: '2vuy'		dimensions: 1280 x 720
# 	}
# 	extensions: {(null)}
# }
# 2023-10-01 20:59:24.445 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 size=16
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyFrameRateRanges self=0x296705028 data(int)=0
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: zrts
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: zrts self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyFrameRate self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyFrameRate self=0x296705028 data(int)=0
# 2023-10-01 20:59:24.446 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyMinimumFrameRate self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) kCMIOStreamPropertyMinimumFrameRate self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Stream(35) kCMIOStreamPropertyMinimumFrameRate self=0x296705028 data(int)=0
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: cafc
# 2023-10-01 20:59:24.447 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: cafc self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for Unknown selector: artd
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) Unknown selector: artd self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyModelUID self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyModelUID self=0x296705028 data(id)=0000
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyManufacturer self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.448 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIOObjectPropertyManufacturer self=0x296705028 data(id)=Digital-iz.inc
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyLinkedCoreAudioDeviceUID self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIODevicePropertySuspendedByUser
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertySuspendedByUser self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyHogMode self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyHogMode self=0x296705028 data(int)=-1
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.449 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: zrts
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: zrts self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyDataSize Device(34) kCMIODevicePropertyStreams self=0x296705028 size=4
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyStreams self=0x296705028 hasProperty=1
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyStreams self=0x296705028 data(int)=35
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: Stream unhandled hasPropertyWithAddress for Unknown selector: sfam
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Stream(35) Unknown selector: sfam self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.450 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.451 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.451 Python[1430:22733] CMIOMS: Device unhandled hasPropertyWithAddress for kCMIOObjectPropertyOwnedObjects
# 2023-10-01 20:59:24.451 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIOObjectPropertyOwnedObjects self=0x296705028 hasProperty=0
# 2023-10-01 20:59:24.472 Python[1430:23412] CMIOMS: PlugIn unhandled hasPropertyWithAddress for Unknown selector: ddsc
# 2023-10-01 20:59:24.472 Python[1430:23412] CMIOMS: HardwarePlugIn_ObjectHasProperty PlugIn(33) Unknown selector: ddsc self=0x296705028 hasProperty=0
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 2023-10-01 21:00:09.515 Python[1430:23862] CMIOMS: PlugIn unhandled hasPropertyWithAddress for Unknown selector: ddsc
# 2023-10-01 21:00:09.515 Python[1430:23862] CMIOMS: HardwarePlugIn_ObjectHasProperty PlugIn(33) Unknown selector: ddsc self=0x296705028 hasProperty=0
# 2023-10-01 21:00:09.597 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectHasProperty Device(34) kCMIODevicePropertyDeviceIsRunningSomewhere self=0x296705028 hasProperty=1
# 2023-10-01 21:00:09.597 Python[1430:22733] CMIOMS: HardwarePlugIn_ObjectGetPropertyData Device(34) kCMIODevicePropertyDeviceIsRunningSomewhere self=0x296705028 data(int)=1

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.51092571,  0.64469892, -0.68075341, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.51092571,  0.64469892, -0.68075341, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['yes', 'no', 'sleep', 'eat', 'dirty'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    # for sequence in range(1,no_sequences+1):
    for sequence in range(no_sequences):

        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(3000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> cap = cv2.VideoCapture(0)
#       <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> # Set mediapipe model
#       <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#       <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a>     # NEW LOOP
#       <a href='vscode-notebook-cell:/Users/divyash/Documents/Dev/Projects/BSL-Word-Level/main.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a>     # Loop through actions
#
# NameError: name 'cv2' is not defined

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (180, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (180,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (180, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (9, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'hello'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[5, 0],
#         [0, 4]],
#
#        [[5, 0],
#         [0, 4]],
#
#        [[8, 0],
#         [0, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
